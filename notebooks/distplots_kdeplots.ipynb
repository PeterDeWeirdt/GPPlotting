# %% [markdown]
# # distplots and kdeplots in seaborn

# %% [markdown]
# Author: Marissa Feeley

# %% [markdown]
# We will be using the mpg dataset to plot. Reference code here: https://seaborn.pydata.org/generated/seaborn.distplot.html https://seaborn.pydata.org/generated/seaborn.kdeplot.html

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import gpplotting as gpp
import seaborn as sns
mpg = sns.load_dataset("mpg")
#I'll be using the mpg dataset for plotting distplots and kdeplots

# %% [markdown]
# ## distplots

# %% [markdown]
# ## Set2 color palette

# %%
#setting style of plot. Color codes allow colors to be called using the ColorBlender id. 
sns.set(style="ticks", palette="Set2", color_codes=True)

# %%
df = mpg['mpg']

# %%
sns.distplot(df)

# %%
#specify color in the distplot with the colorblender color id 
sns.distplot(df, color = '#fc8d62')

# %%
#remove distribution, specify color, add axis label and data label.
sns.distplot(df, hist = False, color="#8da0cb", axlabel="Miles Per Gallon", label="mpg")

# %%
sns.distplot(df, color="#ffd92f", axlabel="Miles Per Gallon")

# %% [markdown]
# ## Paired color palette.

# %%
#setting style of plot. Color codes allow colors to be called using the ColorBlender id. 
sns.set(style="ticks", palette="Paired", color_codes=True)

# %%
sns.distplot(df,axlabel="Miles Per Gallon")

# %%
sns.distplot(df, hist=False, color='#e31a1c', axlabel="Miles Per Gallon",label='mpg')

# %%
sns.distplot(df, color='#1f78b4', axlabel="Miles Per Gallon")

# %%
sns.distplot(df,hist=False, color='#ff7f00', axlabel="Miles Per Gallon",label='mpg')

# %%
sns.distplot(df, color='#33a02c', axlabel="Miles Per Gallon")

# %% [markdown]
# # kdeplots

# %% [markdown]
# ## Set2 color palette.

# %%
#setting style of plot. Color codes allow colors to be called using the ColorBlender id. 
sns.set(style="ticks", palette="Set2", color_codes=True)

# %%
mpg = sns.load_dataset("mpg")
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
#plotting the first and fifth column of the dataset.
sns.kdeplot(mpg.iloc[:,0],mpg.iloc[:,4])

# %%
#plotting the first and fifth column of the dataset. Now playing with the plot settings.
sns.kdeplot(mpg.iloc[:,0],mpg.iloc[:,4], color='#e78ac3', cbar=True)

# %%
#plotting the first and fifth column of the dataset. Now playing with the plot settings.
sns.kdeplot(mpg.iloc[:,0],mpg.iloc[:,4], shade=True,color='#a6d854',shade_lowest=False, cbar=True)

# %% [markdown]
# ## Paired color palette.

# %%
#setting style of plot. Color codes allow colors to be called using the ColorBlender id. 
sns.set(style="ticks", palette="Paired", color_codes=True)

# %%
#plotting the first and fifth column of the dataset. Now playing with the plot settings.
sns.kdeplot(mpg.iloc[:,0],mpg.iloc[:,4], cbar=True)

# %%
#plotting the first and fifth column of the dataset. Now playing with the plot settings.
sns.kdeplot(mpg.iloc[:,0],mpg.iloc[:,4],shade=True,color='#b2df8a',shade_lowest=False, cbar=True)

# %%
#plotting the first and fifth column of the dataset. Now playing with the plot settings.
sns.kdeplot(mpg.iloc[:,0],mpg.iloc[:,4],color='#e31a1c', cbar=True)
